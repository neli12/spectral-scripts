# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl
import glob
import os
from ntpath import basename, splitext
 
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
 
from scipy.signal import savgol_filter
import warnings
warnings.filterwarnings("ignore")

# %%
files = glob.glob(os.path.join(path,'*.csv'))

# %%
# Please use meaningful variable names:
basenames = []

for doc_path in files:

    # Please don't reinvent the wheel.
    # Use the builtin path handling functions.
    # File naming has a lot of exceptions and weird cases 
    # (particularly on Windows).
    file_name = basename(doc_path)
    file_basename, extension = splitext(file_name)
    if extension == ".csv":
        basenames.append(file_basename)

print(basenames)
# Out:
# ['BIOHEDGE-SOG096976_2022-06-14T04-55-33', 'BIOHEDGE-SOG096977_2022-06-14T04-56-28', 'BIOHEDGE-SOG096978_2022-06-14T04-57-14', 'BIOHEDGE-SOG096979_2022-06-14T04-58-18', 'BIOHEDGE-SOG096980_2022-06-14T04-59-03', 'BIOHEDGE-SOG097001_2022-06-14T04-09-13', 'BIOHEDGE-SOG097002_2022-06-14T04-10-06', 'BIOHEDGE-SOG097004_2022-06-14T04-13-48', 'BIOHEDGE-SOG097005_2022-06-14T04-15-50', 'BIOHEDGE-SOG097006_2022-06-14T04-18-04', 'BIOHEDGE-SOG097007_2022-06-14T04-19-38', 'BIOHEDGE-SOG097008_2022-06-14T04-20-27', 'BIOHEDGE-SOG097009_2022-06-14T04-21-15', 'BIOHEDGE-SOG097010_2022-06-14T04-22-22', 'BIOHEDGE-SOG097011_2022-06-14T04-23-13', 'BIOHEDGE-SOG097012_2022-06-14T04-24-21', 'BIOHEDGE-SOG097013_2022-06-14T04-27-53', 'BIOHEDGE-SOG097014_2022-06-14T04-29-13', 'BIOHEDGE-SOG097015_2022-06-14T04-30-05', 'BIOHEDGE-SOG097016_2022-06-14T04-30-52', 'BIOHEDGE-SOG097017_2022-06-14T04-31-39', 'BIOHEDGE-SOG097018_2022-06-14T04-32-28', 'BIOHEDGE-SOG097527_2022-06-14T04-48-37', 'BIOHEDGE-SOG097528_2022-06-14T04-51-13', 'BIOHEDGE-SOG097537_2022-06-14T04-52-00', 'BIOHEDGE-SOG097538_2022-06-14T04-52-51', 'BIOHEDGE-SOG097547_2022-06-14T04-53-42', 'BIOHEDGE-SOG097548_2022-06-14T04-54-30']

# %%
basenames_new  = [i.split('_2022', 1)[0] for i in basenames]
id_names = [i.split('BIOHEDGE-', 1)[1] for i in basenames_new]
id_names.insert(0, 'Wavenumber')
id_names
# Out:
# ['Wavenumber',
#  'SOG096976',
#  'SOG096977',
#  'SOG096978',
#  'SOG096979',
#  'SOG096980',
#  'SOG097001',
#  'SOG097002',
#  'SOG097004',
#  'SOG097005',
#  'SOG097006',
#  'SOG097007',
#  'SOG097008',
#  'SOG097009',
#  'SOG097010',
#  'SOG097011',
#  'SOG097012',
#  'SOG097013',
#  'SOG097014',
#  'SOG097015',
#  'SOG097016',
#  'SOG097017',
#  'SOG097018',
#  'SOG097527',
#  'SOG097528',
#  'SOG097537',
#  'SOG097538',
#  'SOG097547',
#  'SOG097548']

# %%
dataframes = [pd.read_csv(f) for f in files]

# %%
def reduce(function, iterable, initializer=None):
    it = iter(iterable)
    if initializer is None:
        value = next(it)
    else:
        value = initializer
    for element in it:
        value = function(value, element)
    return value

df_merged = reduce(lambda left, right: pd.merge(left, right, on = 'Wavenumber', how = 'outer'), dataframes)

# %%
df_merged.columns = id_names

# %%
df_merged.shape
# Out:
# (3596, 29)

# %%
df_merged.head()
# Out:
#    Wavenumber  SOG096976  SOG096977  SOG096978  SOG096979  SOG096980  \
# 0         650   5.339301   1.499050   3.488021   4.967658   4.955530
# 1         651   5.813316   3.559210   5.705764   6.437532   6.727562
# 2         652   5.191623   4.129518   4.157185   4.983297   6.320817
# 3         653   3.831078   4.083352   1.016578   2.275224   4.129225
# 4         654   3.923971   5.378190   0.280045   1.839424   3.191216
#
#    SOG097001  SOG097002  SOG097004  SOG097005  ...  SOG097015  SOG097016  \
# 0   1.841816   3.859263   3.003718   0.000010  ...   1.330091   2.368278
# 1   1.928635   4.294497   3.830015   1.508527  ...   1.697372   2.618339
# 2   0.000010   2.972787   3.214691   3.056192  ...   2.037935   0.937674
# 3   0.000010   0.099812   1.872065   2.263256  ...   2.349417   0.000010
# 4   0.000010   0.000010   1.822128   1.499067  ...   4.259833   0.682313
#
#    SOG097017  SOG097018  SOG097527  SOG097528  SOG097537  SOG097538  \
# 0   0.332137   2.143862   4.373419   8.976367   3.873219   6.039929
# 1   0.573760   2.764627   5.391403   8.285902   3.793475   6.450260
# 2   0.819564   2.809715   3.304479   5.114044   2.008535   6.175025
# 3   0.842188   2.599404   0.614418   1.716332   0.389996   6.579527
# 4   2.033175   3.481404   0.901971   1.372303   1.617383   8.422524
#
#    SOG097547  SOG097548
# 0   2.319238   2.228072
# 1   3.457124   1.941637
# 2   3.275428   0.521531
# 3   3.157746   0.000010
# 4   4.890372   2.251391
#
# [5 rows x 29 columns]

# %%
df_merged['Wavenumber'] = df_merged['Wavenumber'].round(0).astype('int')

# %%
df_merged.to_csv("df_merged.csv")

# %%
df1_trans = df_merged.set_index('Wavenumber').T
df1_trans.insert(0, 'Sample ID', df1_trans.index)

# %%
df1_trans.reset_index(inplace = True, drop = True)

# %%
df1_trans.head()
# Out:
# Wavenumber  Sample ID  650.4205  651.3523  652.2841   653.216  654.1478  \
# 0           SOG096976  5.339301  5.813316  5.191623  3.831078  3.923971
# 1           SOG096977  1.499050  3.559210  4.129518  4.083352  5.378190
# 2           SOG096978  3.488021  5.705764  4.157185  1.016578  0.280045
# 3           SOG096979  4.967658  6.437532  4.983297  2.275224  1.839424
# 4           SOG096980  4.955530  6.727562  6.320817  4.129225  3.191216
#
# Wavenumber  655.0796  656.0115  656.9433  657.8751  ...  3991.9788  3992.9107  \
# 0           4.778427  4.636455  4.484315  5.588830  ...  80.128433  79.881936
# 1           6.601518  5.823354  4.488095  4.746883  ...  76.479494  76.408214
# 2           0.839366  0.000010  0.000010  0.000010  ...  59.837764  59.247717
# 3           2.939722  3.074332  2.996978  4.206669  ...  89.548594  89.643503
# 4           3.649213  3.278726  2.391073  3.021998  ...  72.295031  72.076491
#
# Wavenumber  3993.8425  3994.7743  3995.7062   3996.638  3997.5698  3998.5017  \
# 0           80.480237  81.152621  81.333001  81.117958  80.776530  80.419133
# 1           76.521606  76.255129  75.782400  75.698871  76.067100  76.399546
# 2           58.874832  58.213424  57.338738  57.030356  57.635755  58.516150
# 3           90.027703  90.143119  89.823094  89.282078  88.631148  87.952851
# 4           71.766228  70.971789  69.960453  69.433274  69.552605  69.823534
#
# Wavenumber  3999.4335  4000.3653
# 0           80.178999  80.218194
# 1           76.458680  76.427402
# 2           59.014094  59.246489
# 3           87.559034  87.636642
# 4           69.954061  70.139841
#
# [5 rows x 3597 columns]

# %%
df1_trans['Sample ID'].tolist()
# Out:
# ['SOG096976',
#  'SOG096977',
#  'SOG096978',
#  'SOG096979',
#  'SOG096980',
#  'SOG097001',
#  'SOG097002',
#  'SOG097004',
#  'SOG097005',
#  'SOG097006',
#  'SOG097007',
#  'SOG097008',
#  'SOG097009',
#  'SOG097010',
#  'SOG097011',
#  'SOG097012',
#  'SOG097013',
#  'SOG097014',
#  'SOG097015',
#  'SOG097016',
#  'SOG097017',
#  'SOG097018',
#  'SOG097527',
#  'SOG097528',
#  'SOG097537',
#  'SOG097538',
#  'SOG097547',
#  'SOG097548']

# %%
toc = pd.read_csv("BioHedgeTOC.csv")
print(toc['Sample ID'].tolist())
# Out:
# ['SOG096976',
#  'SOG096977',
#  'SOG096978',
#  'SOG096979',
#  'SOG096980',
#  'SOG097001',
#  'SOG097002',
#  'SOG097004',
#  'SOG097005',
#  'SOG097006',
#  'SOG097007',
#  'SOG097008',
#  'SOG097009',
#  'SOG097010',
#  'SOG097011',
#  'SOG097012',
#  'SOG097013',
#  'SOG097014',
#  'SOG097015',
#  'SOG097016',
#  'SOG097517',
#  'SOG097518',
#  'SOG097527',
#  'SOG097528',
#  'SOG097537',
#  'SOG097538',
#  'SOG097547',
#  'SOG097548']

# %%
df_def = pd.merge(toc, df1_trans, on = 'Sample ID')
df_def
# Out:
#     Sample ID   %TOC  650.4205  651.3523  652.2841   653.216  654.1478  \
# 0   SOG096976  3.593  5.339301  5.813316  5.191623  3.831078  3.923971
# 1   SOG096977  2.341  1.499050  3.559210  4.129518  4.083352  5.378190
# 2   SOG096978  2.117  3.488021  5.705764  4.157185  1.016578  0.280045
# 3   SOG096979  1.114  4.967658  6.437532  4.983297  2.275224  1.839424
# 4   SOG096980  1.303  4.955530  6.727562  6.320817  4.129225  3.191216
# 5   SOG097001  3.529  1.841816  1.928635  0.000010  0.000010  0.000010
# 6   SOG097002  2.485  3.859263  4.294497  2.972787  0.099812  0.000010
